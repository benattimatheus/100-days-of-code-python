# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.") 

choice1 = input('''You're at a cross road. Where do you want to go? Type "left" or right" ''').lower()

if choice1 == "left":
    print('''
    

            ]=[
          .'   `.             `.-v-.'
.-._.._  /_______\ ..--.`-._
       `-|  .---.|          `--.._                    `.-v-.'
         |  |.-.||           _..--`
 `.-o-.' |  |'-'||     _..--`               `.-o-.'
     .-..|  '---'|..--`                              .--.
-._.`   _|..---..|_                                .`    `-._
       |__..---..__|                              `--.._     `--.._
        |  _ | |_||     `.-v-.'          `.-v-.'        `--.._     `.
        | |_||   _|                                           `--..`
      __|_..---.._|__
     |___...---...___|
      |  _   |     _|              `.-o-.'
      | | | _| _    |
      | |_|  |    _ |      _....--```.                       `.-v-.'
      | _    |   | ||..--``     ..-..`          `.-o-.'
   _..|   _  |_  |_||       ..``
 -`   |  | | |    _ |   _.-`
      |  |_| |  _   |.-`             __       __
      | _    | | |  |                ||       ||
  .--`|  _   | |_|  |        ________||_______||
      | | | _|     _|       /_ _ _ _/ \\_ _ _/ \\
      | | |  | _    |      /_ _ _ _/   \\_ _/ _ \\
      |__...---...__|     /_ _ _ _/_   _\\ / | | \\   `.::::::::::::::::::
  _..-'__...---...__'-._ /_ _ _ _/| | | |\\  |_| |\\    `-._::::::::::::::
 |_..-'      |  _   '-._/_______/ |_| |_| \\    _|          `.::::::::::::
  | _      _ |       _  |   _  |_ _ _ _ _ _ _ _ _|   .,       `-.:::::::::
  |     _    | _        |  _   |_|_|_|_|_|_|_|_|_|         ,.    `.:::::::
  |  _      _|     _    | | | -| _           _   |  .,             `.:::::
  |_.   .-._ | _       _| | |  |      _   _______|_             .,   `-.::
-'   `-'    `'._.`-._.--'`--.._|  _      /_ _ _ _ /\    ,.           ,. `.
`...    .,                   ., `-._  _ / _ _ _ _/ -\                 _.-
    `.           ,.      .,         `-./_ _ _ _ /  _ \      ,.    _.-`::::
    .'     ,.                          `-. ____/| |_||\        .-'::::::::
 _.'                                ,.    `-.  -|   _|       .':::::::::::
             .,       ,.                     `. |-__ | .,  .':::::::::::::
                                 ,.            \||  ||   .-'::::::::::::::
     .,                    ,.            ,.     ||  || .':::::::::::::::::
                  .,                       __.--.:::::':::::::::::::::::::
       _.-``-._=:..-_.,=`:;.,-=.'-._..---``..:::::::::::::::::::::::::::::
``--..` ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

    ''')
    choice2 = input('''\nYou've come to a lake. There is an island in the middle of the lake with a lighthouse in it. Type "wait" to wait for a boat. Type "swim" to swim across.''').lower()
    if choice2 == "wait":
      print('''
                 ;~
               ./|\.
             ./ /| `\.
            /  | |   `\.
           |   | |     `\.
           |    \|       `\.
         .  `----|__________\.
          \-----''----.....___
          \               ""/
      ~^~^~^~^~^`~^~^`^~^~^`^~^~^
       ~^~^~`~~^~^`~^~^~`~~^~^~
      ''')
      choice3 = input('''The boat arrives and you are taken to the island. The lighthouse in right in front of you. Type "enter" to enter the lighthouse. Type "stay" to stay outside.''')
      if choice3 == "enter":
        choice4 = input('''You enter the lighthouse and it is bigger than you thought. You look around and see a stair that can go up or down. Type "up" to go upstairs. Type "down" to go downstairs''')
        if choice4 == "up":
          print('''
                            .

                   .
         /^\     .
    /\   "V"
   /__\   I      O  o
  //..\\  I     .
  \].`[/  I
  /l\/j\  (]    .  O
 /. ~~ ,\/I          .
 \\L__j^\/I       o
  \/--v}  I     o   .
  |    |  I   _________
  |    |  I c(`       ')o
  |    l  I   \.     ,/
_/j  L l\_!  _//^---^\\_ 
''')
          print("\nYou found a wizard. He gives you some silver coins. You win!")
        else:
          print('''
                    \||/
                |  @___oo
      /\  /\   / (__,,,,|
     ) /^\) ^\/ _)
     )   /^\/   _)
     )   _ /  / _)
 /\  )/\/ ||  | )_)
<  >      |(,,) )__)
 ||      /    \)___)\
 | \____(      )___) )___
  \______(_______;;; __;;;
          ''')
          print("\nYou found a friendly dragon. You drink some tea with him and go back home. You win!")
      else:
        print("\nYou walk around the island and find some fruits that look delicious. As soon as you start eating them, you see some monkeys in the trees laughing at you.")
        print('''\n
             .-"""-.
             _/-=-.   \
            (_|o o/   |_
             / "  \   ,_)
        _    \`=' /__/
       / \_  .;--'  `-.
       \___)//      ,  \
        \ \/;        \  \
         \_.|         | |
          .-\ '     _/_/
        .'  _;.    (_  \
       /  .'   `\   \\_/
      |_ /       |  |\\
     /  _)       /  / ||
jgs /  /       _/  /  //
    \_/       ( `-/  ||
              /  /   \\ .-.
              \_/     \'-'/
    ''')
        print('''\n
         ,--./,-.
        /,-._.--~\
         __}  {
        \`-._,-`-,
         `._,._,'
        ''')
        print("\nIt was a poisonous fruit. Game Over")
        
    else:
      print('''\nYou start to swim and soon hear the water splashing behind you. You continue swimming and the water splashes again. As soon as you look back a crocodile jumps on you.\n''')
      print(''' 
      
                     _.---._     .---.
            __...---' .---. `---'-.   `.
        .-''__.--' _.'( | )`.  `.  `._ :
      .'__-'_ .--'' ._`---'_.-.  `.   `-`.
             ~ -._ -._``---. -.    `-._   `.
                  ~ -.._ _ _ _ ..-_ `.  `-._``--.._
                               -~ -._  `-.  -. `-._``--.._.--''.
                                    ~ ~-.__     -._  `-.__   `. `.
                                         ~~ ~---...__ _    ._ .` `.
                                                      ~  ~--.....--~`
                                                      ''')
      print("\nGame Over")

else:
  print('''
    
                                       +---+
                                      |\   \
  +-----------------------------+     | +---+
   \                      +-----------+ |   |
    \                      \            |   |
     \                 |/   +-----------+   |
      \                (o_      |   \ | |   |
       \                \       |    \| |   |
        \                       |     | |   |
         \                      |     + |   |
          \                     |      \|   |
           \--------------------+       +---+
            \                    \        \
             \                    \        \
              +-----------------------------+
              
              ''')
  print("You fell into a hole.")
  print("Game Over")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
