# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Bem vindo à Ilha do Tesouro")
print("Sua missão é achar o tesouro.") 

choice1 = input('''Você está em uma encruzilhada para onde quer ir? Digite "esquerda" ou "direita" ''').lower()

if choice1 == "esquerda":
    print('''
    

            ]=[
          .'   `.             `.-v-.'
.-._.._  /_______\ ..--.`-._
       `-|  .---.|          `--.._                    `.-v-.'
         |  |.-.||           _..--`
 `.-o-.' |  |'-'||     _..--`               `.-o-.'
     .-..|  '---'|..--`                              .--.
-._.`   _|..---..|_                                .`    `-._
       |__..---..__|                              `--.._     `--.._
        |  _ | |_||     `.-v-.'          `.-v-.'        `--.._     `.
        | |_||   _|                                           `--..`
      __|_..---.._|__
     |___...---...___|
      |  _   |     _|              `.-o-.'
      | | | _| _    |
      | |_|  |    _ |      _....--```.                       `.-v-.'
      | _    |   | ||..--``     ..-..`          `.-o-.'
   _..|   _  |_  |_||       ..``
 -`   |  | | |    _ |   _.-`
      |  |_| |  _   |.-`             __       __
      | _    | | |  |                ||       ||
  .--`|  _   | |_|  |        ________||_______||
      | | | _|     _|       /_ _ _ _/ \\_ _ _/ \\
      | | |  | _    |      /_ _ _ _/   \\_ _/ _ \\
      |__...---...__|     /_ _ _ _/_   _\\ / | | \\   `.::::::::::::::::::
  _..-'__...---...__'-._ /_ _ _ _/| | | |\\  |_| |\\    `-._::::::::::::::
 |_..-'      |  _   '-._/_______/ |_| |_| \\    _|          `.::::::::::::
  | _      _ |       _  |   _  |_ _ _ _ _ _ _ _ _|   .,       `-.:::::::::
  |     _    | _        |  _   |_|_|_|_|_|_|_|_|_|         ,.    `.:::::::
  |  _      _|     _    | | | -| _           _   |  .,             `.:::::
  |_.   .-._ | _       _| | |  |      _   _______|_             .,   `-.::
-'   `-'    `'._.`-._.--'`--.._|  _      /_ _ _ _ /\    ,.           ,. `.
`...    .,                   ., `-._  _ / _ _ _ _/ -\                 _.-
    `.           ,.      .,         `-./_ _ _ _ /  _ \      ,.    _.-`::::
    .'     ,.                          `-. ____/| |_||\        .-'::::::::
 _.'                                ,.    `-.  -|   _|       .':::::::::::
             .,       ,.                     `. |-__ | .,  .':::::::::::::
                                 ,.            \||  ||   .-'::::::::::::::
     .,                    ,.            ,.     ||  || .':::::::::::::::::
                  .,                       __.--.:::::':::::::::::::::::::
       _.-``-._=:..-_.,=`:;.,-=.'-._..---``..:::::::::::::::::::::::::::::
``--..` ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

    ''')
    choice2 = input('''\nVocê chegou em um lago. Tem uma ilha no meio do lago com um farol nela. Digite "esperar" para esperar um barco. Digite "nadar" para nadar até a ilha.''').lower()
    if choice2 == "esperar":
      print('''
                 ;~
               ./|\.
             ./ /| `\.
            /  | |   `\.
           |   | |     `\.
           |    \|       `\.
         .  `----|__________\.
          \-----''----.....___
          \               ""/
      ~^~^~^~^~^`~^~^`^~^~^`^~^~^
       ~^~^~`~~^~^`~^~^~`~~^~^~
      ''')
      choice3 = input('''O barco chega e você é levado até a ilha. O farol está bem na sua frente. Digite "entrar" para entrar no farol. Digite "ficar" para ficar fora. ''')
      if choice3 == "entrar":
        choice4 = input('''Você entra no farol e é muito maior do que pensava. Você olha ao redor e vê uma escada que pode ir para cima ou para baixo. Digite "cima" para subir as escadas. Digite "baixo" para descer as escadas.''')
        if choice4 == "cima":
          print('''
                            .

                   .
         /^\     .
    /\   "V"
   /__\   I      O  o
  //..\\  I     .
  \].`[/  I
  /l\/j\  (]    .  O
 /. ~~ ,\/I          .
 \\L__j^\/I       o
  \/--v}  I     o   .
  |    |  I   _________
  |    |  I c(`       ')o
  |    l  I   \.     ,/
_/j  L l\_!  _//^---^\\_ 
''')
          print("\nVocê encontrou um mago. Ele te dá algumas moedas de prata. Você venceu!")
        else:
          print('''
                    \||/
                |  @___oo
      /\  /\   / (__,,,,|
     ) /^\) ^\/ _)
     )   /^\/   _)
     )   _ /  / _)
 /\  )/\/ ||  | )_)
<  >      |(,,) )__)
 ||      /    \)___)\
 | \____(      )___) )___
  \______(_______;;; __;;;
          ''')
          print("\nVocê encontrou um dragão amigável. Você bebe chá com ele e volta para casa. Você venceu!")
      else:
        print("\nVocê anda pela ilha e encontra algumas frutas que parecem deliciosas. Assim que você começa a comer elas, você vê alguns macacos nas árvores rindo de você.")
        print('''\n
             .-"""-.
             _/-=-.   \
            (_|o o/   |_
             / "  \   ,_)
        _    \`=' /__/
       / \_  .;--'  `-.
       \___)//      ,  \
        \ \/;        \  \
         \_.|         | |
          .-\ '     _/_/
        .'  _;.    (_  \
       /  .'   `\   \\_/
      |_ /       |  |\\
     /  _)       /  / ||
jgs /  /       _/  /  //
    \_/       ( `-/  ||
              /  /   \\ .-.
              \_/     \'-'/
    ''')
        print('''\n
         ,--./,-.
        /,-._.--~\
         __}  {
        \`-._,-`-,
         `._,._,'
        ''')
        print("\nEram frutas venenosas. Fim de jogo")
        
    else:
      print('''\nVocê começa a nadar e logo escuta a água espirrando atrás de você. Você continua a nadar e a água espirra de novo. Assim que você olha para ver o que está acontecendo, um crocodilo pula em você.\n''')
      print(''' 
      
                     _.---._     .---.
            __...---' .---. `---'-.   `.
        .-''__.--' _.'( | )`.  `.  `._ :
      .'__-'_ .--'' ._`---'_.-.  `.   `-`.
             ~ -._ -._``---. -.    `-._   `.
                  ~ -.._ _ _ _ ..-_ `.  `-._``--.._
                               -~ -._  `-.  -. `-._``--.._.--''.
                                    ~ ~-.__     -._  `-.__   `. `.
                                         ~~ ~---...__ _    ._ .` `.
                                                      ~  ~--.....--~`
                                                      ''')
      print("\nFim de jogo")

else:
  print('''
    
                                       +---+
                                      |\   \
  +-----------------------------+     | +---+
   \                      +-----------+ |   |
    \                      \            |   |
     \                 |/   +-----------+   |
      \                (o_      |   \ | |   |
       \                \       |    \| |   |
        \                       |     | |   |
         \                      |     + |   |
          \                     |      \|   |
           \--------------------+       +---+
            \                    \        \
             \                    \        \
              +-----------------------------+
              
              ''')
  print("Você caiu em um buraco.")
  print("Fim de jogo")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
